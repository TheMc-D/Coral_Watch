# %%
import os

data_dir = '../data/raw/Coral Reef Images'

for split in ['train', 'valid', 'test']:
    for label in ['Bleached', 'Healthy']:
        path = os.path.join(data_dir, split, label)
        count = len(os.listdir(path))
        print(f"{split}/{label}: {count} images")
# Out:
# train/Bleached: 4980 images
# train/Healthy: 4682 images
# valid/Bleached: 240 images
# valid/Healthy: 223 images
# test/Bleached: 135 images
# test/Healthy: 122 images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random

data_dir = '../data/raw/Coral Reef Images'

fig, axes = plt.subplots(2, 4, figsize=(12, 6))

for col, label in enumerate(['Bleached', 'Healthy']):
    folder = os.path.join(data_dir, 'train', label)
    images = random.sample(os.listdir(folder), 4)
    for row, img_name in enumerate(images):
        img = mpimg.imread(os.path.join(folder, img_name))
        axes[col][row].imshow(img)
        axes[col][row].set_title(label)
        axes[col][row].axis('off')

plt.tight_layout()
plt.show()
